# %% [markdown]
# # The Star Wars social network
#
# I recently looked at the whole Star Wars universe from a computational perspective, where I extracted and analyzed
# social networks from all seven films. The social network structure revealed some interesting differences
# between the individual films, especially between the original trilogy and the prequels. Here I&#8217;ll look at how we
# can represent and explore the same network using a Neo4j database.

# %% [markdown]
# You can read more about my original analysis in my two blog posts, which include additional social
# network analysis and my F# scripts for downloading and extracting the data:

# %% [markdown]
# - [The Star Wars social network](http://evelinag.com/blog/2015/12-15-star-wars-social-network/index.html)

# %% [markdown]
# - [Star Wars social networks: The Force Awakens](http://evelinag.com/blog/2016/01-25-social-network-force-awakens/index.html)

# %% [markdown]
# ## The network
#
# The social network was automatically constructed using the films' screenplays.
# The nodes in the network represent the individual characters who are
# connected by a link if they both speak within the same movie scene.
# The network only includes characters that appear in at least two scenes and
# that are explicitly named in the screenplay (I excluded characters called "PILOT" or even "STAR DESTROYER TECHNICIAN").
# I also separated the characters into two categories: `Person` and `Droid`.
# The interactions create the basic structure of the network, where characters are connected
# by the `SPEAKS_WITH` relation. I also included the information about the individual
# movies using the `APPEARS_IN` relation. The following graph illustrates the general
# network structure:
#
# ![network relations](https://s3-eu-west-1.amazonaws.com/evelinag/network-relations.png)

# %% [markdown]
# ## Setup
#
# Now we can setup the database using the social network from all the 7 movies
# combined together.
# In order to execute Cypher queries, make sure that the IPython extension `icypher` is installed.
# If not, run the following command to install it:

# %%
#%pip install icypher --quiet
#%pip install neo4jupyter --quiet

# %% [markdown]
# Then, load the `icypher` extension:

# %%
# %load_ext icypher

# %% [markdown]
# Now you&#8217;re ready to connect to your Neo4j database:

# %%
# %cypher http://user:passwd@localhost:7474/

# %% [markdown]
# Let&#8217;s look at some basic information from the database. The following query extracts
# all the films that are included in the network.

# %%
# %%cypher
# MATCH (m:Movie)
# RETURN m.name
# Out:
# [{'m.name': 'Episode I: The Phantom Menace'},
#  {'m.name': 'Episode I: The Phantom Menace'},
#  {'m.name': 'Episode II: Attack of the Clones'},
#  {'m.name': 'Episode III: Revenge of the Sith'},
#  {'m.name': 'Episode IV: A New Hope'},
#  {'m.name': 'Episode V: The Empire Strikes Back'},
#  {'m.name': 'Episode VI: Return of the Jedi'},
#  {'m.name': 'Episode VII: The Force Awakens'}]

# %% [markdown]
# It seems that the database correctly contains all the seven episodes of Star Wars.

# %% [markdown]
# ## Simple network properties
#
# Now we can start comparing the individual episodes based on their network properties. Is the original
# trilogy different from the prequels in terms of its social network? And how does The Force Awakens
# compare to the rest?
# Let&#8217;s start with looking at the number of characters in each of the episodes. The following
# query extracts characters and returns their count aggregated by the movie that they appear in.

# %%
# %%cypher
# MATCH (m:Movie)<-[:APPEARS_IN]-(character)
# RETURN m.name AS movie, count(*) AS characters
# ORDER BY m.name;

# %% [markdown]
# We can immediately see some differences between the movies. The original trilogy (Episodes IV to VI)
# has the smallest number of characters. On the other hand, Episode I: The Phantom Menace has the largest number
# of characters, almost twice as many.
# How many interactions are there between the characters? In this query, we extract all the links between
# two characters that both appear within the same movie and return their count for each movie. This is a
# simplification because I&#8217;m assuming that if two characters have link between them, then they interact
# in every movie where they both appear.

# %%
# %%cypher
# MATCH (m)<-[:APPEARS_IN]-(character)-[:SPEAKS_WITH]-(character2)-[:APPEARS_IN]->(m)
# RETURN m.name AS movie, count(*) AS edges
# ORDER BY m.name;

# %% [markdown]
# The results show a similar story, where the original trilogy has smaller number of links
# between the characters and their social networks are smaller. This corresponds to the
# tighter and more organized structure of the original films, which have smaller number of
# characters that bind the story together more.

# %% [markdown]
# ## Extracting social network relations
#
# We can also use the database to extract the social network for each of the Star Wars movies.
# The following query extracts all the characters that appear in a specific episode and
# all the interactions between them. I&#8217;m using the Episode VII
# as an example:

# %%
# %%cypher
# MATCH network=(m)<-[:APPEARS_IN]-(character1)-[r]-(character2)-[:APPEARS_IN]->(m)
# WHERE m.name='Episode VII: The Force Awakens'
# RETURN character1, r, character2

# %% [markdown]
# We can see that there are parts of the network that correspond to the Dark side characters,
# including Snoke, General Hux and others. There is also a cluster of nodes that represent
# Resistance pilots, and who interact mainly with each other and with Poe. Let&#8217;s explore the
# network in more detail.

# %% [markdown]
# ## Importance of characters in the network
#
# A basic measure of centrality in a social network is the **degree centrality**. This is
# simply the number of connections each node has in the network.
# In our Star Wars network, this corresponds to the total number of scenes where each character speaks.
# The following query extracts the number of `SPEAKS_WITH` relations for each character and returns
# the top 10 results.

# %%
# %%cypher
# MATCH (ch1)-[:SPEAKS_WITH]-(ch2)
# RETURN ch1.name AS name, count(*) AS degree
# ORDER BY count(*) DESC LIMIT 10;

# %% [markdown]
# This result is strongly affected by the large social networks of the prequels. Anakin
# comes out at the top as the person that speaks with the largest number of other characters.
# And because of the prequels, even Jar Jar made it into the top 10.

# %% [markdown]
# ## Who has the largest degree?
#
# We can instead look at who has the largest degree within the individual films. This query
# extracts the characters that speak to each other and appear within the same film, and counts
# the number of such connections for each character. I&#8217;m using the orignal Episode IV: A New Hope
# in the example.

# %%
# %%cypher
# MATCH (m)<-[:APPEARS_IN]-(ch1)-[:SPEAKS_WITH]-(ch2)-[:APPEARS_IN]->(m)
# WHERE m.name='Episode IV: A New Hope'
# RETURN ch1.name AS name, count(*) AS degree
# ORDER BY count(*) DESC LIMIT 5;

# %% [markdown]
# Here, Luke Skywalker is the most central character, followed by Leia and the droids.
# We can also visualize the results and look at the specific interactions.
# For example, the following query extracts all the
# characters that interact with Luke Skywalker, together with the movies that they appear in.

# %%
# %%cypher
# MATCH path=(luke:Person {name: 'LUKE'})-[:SPEAKS_WITH]-(other)-[:APPEARS_IN]-(movie)
# RETURN path

# %% [markdown]
# Here we can see that some of the characters cluster around specific episodes (these are the
# characters that appear only the specific episode). Other characters that interact with Luke
# across several other episodes appear as more central nodes in the network.

# %% [markdown]
# ## Summary
#
# This GraphGist showed how to do simple social network analysis using the
# Star Wars social network that I extracted from the film scripts. We looked at how to
# extract and summarize sub-networks for individual episodes, and for specific characters.
# Overall, this was my first experience with Neo4j and it was very easy to create the network and
# extract interesting information from the database.

# %%
# !pip install py2neo
import neo4jupyter
neo4jupyter.init_notebook_mode()

# %%
from py2neo import Graph
g=Graph("http://localhost:7474/")
print(g)
neo4jupyter.draw(g, options = {'Person':"name"})

# %% [markdown]
# Some extra code cells based on questions:

# %% [markdown]
# First, see if we can get all relationships:

# %%
# %%cypher
# MATCH (n)-[r]->(m) RETURN n.name,type(r),m.name

# %%
# %%cypher
# MATCH (n:Person{name:"YODA"})-[r*0..2]-(m)
#
# RETURN n.name,r,m.name
# Out:
# [{'n.name': 'YODA', 'r': [], 'm.name': 'YODA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CHEWBACCA'), Node('Droid', name='R2-D2'))],
#   'm.name': 'CHEWBACCA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Droid', name='BB-8'), Node('Droid', name='R2-D2'))],
#   'm.name': 'BB-8'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Droid', name='R2-D2'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='PADME'), Node('Droid', name='R2-D2'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='QUI-GON'), Node('Droid', name='R2-D2'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Droid', name='R2-D2'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='WATTO'))],
#   'm.name': 'WATTO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Droid', name='C-3PO'), Node('Droid', name='R2-D2'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KITSTER'), Node('Droid', name='R2-D2'))],
#   'm.name': 'KITSTER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JABBA'), Node('Droid', name='R2-D2'))],
#   'm.name': 'JABBA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='EMPEROR'), Node('Droid', name='R2-D2'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAPTAIN TYPHO'), Node('Droid', name='R2-D2'))],
#   'm.name': 'CAPTAIN TYPHO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BERU'), Node('Droid', name='R2-D2'))],
#   'm.name': 'BERU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OWEN'), Node('Droid', name='R2-D2'))],
#   'm.name': 'OWEN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Droid', name='R2-D2'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Droid', name='R2-D2'))],
#   'm.name': 'LUKE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LEIA'), Node('Droid', name='R2-D2'))],
#   'm.name': 'LEIA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAPTAIN ANTILLES'), Node('Droid', name='R2-D2'))],
#   'm.name': 'CAPTAIN ANTILLES'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BIGGS'), Node('Droid', name='R2-D2'))],
#   'm.name': 'BIGGS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='DARTH VADER'), Node('Droid', name='R2-D2'))],
#   'm.name': 'DARTH VADER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='HAN'), Node('Droid', name='R2-D2'))],
#   'm.name': 'HAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LANDO'), Node('Droid', name='R2-D2'))],
#   'm.name': 'LANDO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode VII: The Force Awakens'))],
#   'm.name': 'Episode VII: The Force Awakens'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode IV: A New Hope'))],
#   'm.name': 'Episode IV: A New Hope'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode V: The Empire Strikes Back'))],
#   'm.name': 'Episode V: The Empire Strikes Back'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode VI: Return of the Jedi'))],
#   'm.name': 'Episode VI: Return of the Jedi'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Droid', name='R2-D2'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA'))],
#   'm.name': 'SENATOR ASK AAK'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='EMPEROR'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ORN FREE TAA'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'ORN FREE TAA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='MACE WINDU'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='SENATOR ASK AAK'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='SENATOR ASK AAK'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER GREE'), Node('Person', name='YODA'))],
#   'm.name': 'CLONE COMMANDER GREE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER GREE'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='CLONE COMMANDER GREE'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Droid', name='R2-D2'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='CLIEGG'))],
#   'm.name': 'CLIEGG'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='RABE'))],
#   'm.name': 'RABE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='LUKE'))],
#   'm.name': 'LUKE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='GREEDO'))],
#   'm.name': 'GREEDO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='SUN RIT'))],
#   'm.name': 'SUN RIT'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='BOSS NASS'))],
#   'm.name': 'BOSS NASS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='BERU'))],
#   'm.name': 'BERU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='CAPTAIN TYPHO'))],
#   'm.name': 'CAPTAIN TYPHO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='KITSTER'))],
#   'm.name': 'KITSTER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='ANAKIN'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='CAPTAIN PANAKA'))],
#   'm.name': 'CAPTAIN PANAKA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='SEBULBA'))],
#   'm.name': 'SEBULBA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='PADME'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='NUTE GUNRAY'))],
#   'm.name': 'NUTE GUNRAY'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='ANAKIN'), Node('Movie', name='Episode VI: Return of the Jedi'))],
#   'm.name': 'Episode VI: Return of the Jedi'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='CLONE COMMANDER CODY'))],
#   'm.name': 'CLONE COMMANDER CODY'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='QUI-GON'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='EMPEROR'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='JOBAL'))],
#   'm.name': 'JOBAL'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='ANAKIN'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='WALD'))],
#   'm.name': 'WALD'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='BRAVO THREE'))],
#   'm.name': 'BRAVO THREE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='ODD BALL'))],
#   'm.name': 'ODD BALL'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='POGGLE'))],
#   'm.name': 'POGGLE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='DARTH VADER'))],
#   'm.name': 'DARTH VADER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='JIRA'))],
#   'm.name': 'JIRA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='BAIL ORGANA'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='OWEN'))],
#   'm.name': 'OWEN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Droid', name='C-3PO'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='SHMI'))],
#   'm.name': 'SHMI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='JAR JAR'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='MACE WINDU'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='KI-ADI-MUNDI'))],
#   'm.name': 'KI-ADI-MUNDI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='WATTO'))],
#   'm.name': 'WATTO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='ANAKIN'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='JABBA'))],
#   'm.name': 'JABBA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='SIO BIBBLE'))],
#   'm.name': 'SIO BIBBLE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='GENERAL GRIEVOUS'))],
#   'm.name': 'GENERAL GRIEVOUS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='BRAVO TWO'))],
#   'm.name': 'BRAVO TWO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='COUNT DOOKU'))],
#   'm.name': 'COUNT DOOKU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='RIC OLIE'))],
#   'm.name': 'RIC OLIE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='RUWEE'))],
#   'm.name': 'RUWEE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='SOLA'))],
#   'm.name': 'SOLA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Droid', name='R2-D2'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='JAR JAR'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Droid', name='C-3PO'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='EMPEROR'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='BAIL ORGANA'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='KI-ADI-MUNDI'))],
#   'm.name': 'KI-ADI-MUNDI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='GIDDEAN DANU'))],
#   'm.name': 'GIDDEAN DANU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'SENATOR ASK AAK'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='PADME'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='CAPTAIN ANTILLES'))],
#   'm.name': 'CAPTAIN ANTILLES'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='VALORUM'))],
#   'm.name': 'VALORUM'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='QUI-GON'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='MON MOTHMA'))],
#   'm.name': 'MON MOTHMA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='FANG ZAR'))],
#   'm.name': 'FANG ZAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='BAIL ORGANA'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='BAIL ORGANA'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='MACE WINDU'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='BAIL ORGANA'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='NUTE GUNRAY'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'NUTE GUNRAY'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='PLO KOON'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'PLO KOON'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Droid', name='C-3PO'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='PADME'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='FANG ZAR'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'FANG ZAR'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='BAIL ORGANA'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='GENERAL GRIEVOUS'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'GENERAL GRIEVOUS'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='COUNT DOOKU'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'COUNT DOOKU'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='EMPEROR'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='CAPTAIN ANTILLES'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'CAPTAIN ANTILLES'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='MACE WINDU'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='QUI-GON'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='MON MOTHMA'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'MON MOTHMA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='ANAKIN'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='JAR JAR'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='ODD BALL'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'ODD BALL'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='DARTH VADER'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'DARTH VADER'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='GIDDEAN DANU'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'GIDDEAN DANU'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='TION MEDON'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'TION MEDON'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='CLONE COMMANDER CODY'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'CLONE COMMANDER CODY'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='CAPTAIN TYPHO'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'CAPTAIN TYPHO'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode III: Revenge of the Sith')),
#    APPEARS_IN(Node('Person', name='CLONE COMMANDER GREE'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'CLONE COMMANDER GREE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='RABE'), Node('Person', name='YODA'))],
#   'm.name': 'RABE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='RABE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='RABE'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='RABE'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='RABE'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='RABE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='QUI-GON'), Node('Person', name='RABE'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='RABE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='RABE'))],
#   'm.name': 'KI-ADI-MUNDI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='RABE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='MACE WINDU'), Node('Person', name='RABE'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Droid', name='R2-D2'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CHEWBACCA'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'CHEWBACCA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='QUI-GON'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='SHMI'))],
#   'm.name': 'SHMI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JANGO FETT'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'JANGO FETT'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='TION MEDON'))],
#   'm.name': 'TION MEDON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='HAN'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'HAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='SIO BIBBLE'))],
#   'm.name': 'SIO BIBBLE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='GENERAL GRIEVOUS'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'GENERAL GRIEVOUS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'CLONE COMMANDER CODY'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode VI: Return of the Jedi'))],
#   'm.name': 'Episode VI: Return of the Jedi'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'SENATOR ASK AAK'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'KI-ADI-MUNDI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode IV: A New Hope'))],
#   'm.name': 'Episode IV: A New Hope'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='DARTH VADER'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'DARTH VADER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LAMA SU'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'LAMA SU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode V: The Empire Strikes Back'))],
#   'm.name': 'Episode V: The Empire Strikes Back'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Droid', name='C-3PO'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='TAUN WE'))],
#   'm.name': 'TAUN WE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAPTAIN TYPHO'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'CAPTAIN TYPHO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='ODD BALL'))],
#   'm.name': 'ODD BALL'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='SUN RIT'))],
#   'm.name': 'SUN RIT'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BOSS NASS'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'BOSS NASS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAPTAIN PANAKA'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'CAPTAIN PANAKA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='POGGLE'))],
#   'm.name': 'POGGLE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='EMPEROR'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='RIC OLIE'))],
#   'm.name': 'RIC OLIE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='MACE WINDU'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'LUKE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='COUNT DOOKU'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'COUNT DOOKU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='NUTE GUNRAY'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'NUTE GUNRAY'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BOBA FETT'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'BOBA FETT'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='TC-14'))],
#   'm.name': 'TC-14'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='PADME'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LEIA'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'LEIA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='OBI-WAN'), Node('Person', name='PK-4'))],
#   'm.name': 'PK-4'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='JAR JAR'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BOSS NASS'), Node('Person', name='JAR JAR'))],
#   'm.name': 'BOSS NASS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='VALORUM'))],
#   'm.name': 'VALORUM'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAPTAIN TYPHO'), Node('Person', name='JAR JAR'))],
#   'm.name': 'CAPTAIN TYPHO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='MACE WINDU'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='FODE/BEED'), Node('Person', name='JAR JAR'))],
#   'm.name': 'FODE/BEED'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='RIC OLIE'))],
#   'm.name': 'RIC OLIE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='SEBULBA'))],
#   'm.name': 'SEBULBA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='JAR JAR'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='GENERAL CEEL'), Node('Person', name='JAR JAR'))],
#   'm.name': 'GENERAL CEEL'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='SHMI'))],
#   'm.name': 'SHMI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='WALD'))],
#   'm.name': 'WALD'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAPTAIN PANAKA'), Node('Person', name='JAR JAR'))],
#   'm.name': 'CAPTAIN PANAKA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JABBA'), Node('Person', name='JAR JAR'))],
#   'm.name': 'JABBA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='SENATOR ASK AAK'))],
#   'm.name': 'SENATOR ASK AAK'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='QUI-GON'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='PADME'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='JAR JAR'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='KITSTER'))],
#   'm.name': 'KITSTER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='SIO BIBBLE'))],
#   'm.name': 'SIO BIBBLE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='JAR JAR'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='JAR JAR'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='EMPEROR'), Node('Person', name='JAR JAR'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='TARPALS'))],
#   'm.name': 'TARPALS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JAR JAR'), Node('Person', name='ORN FREE TAA'))],
#   'm.name': 'ORN FREE TAA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA'))],
#   'm.name': 'KI-ADI-MUNDI'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='EMPEROR'), Node('Person', name='KI-ADI-MUNDI'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='KI-ADI-MUNDI'), Node('Movie', name='Episode II: Attack of the Clones'))],
#   'm.name': 'Episode II: Attack of the Clones'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BAIL ORGANA'), Node('Person', name='KI-ADI-MUNDI'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='MACE WINDU'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='RABE'))],
#   'm.name': 'RABE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='KI-ADI-MUNDI'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'Episode I: The Phantom Menace'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='PLO KOON'))],
#   'm.name': 'PLO KOON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='KI-ADI-MUNDI'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='KI-ADI-MUNDI'), Node('Person', name='QUI-GON'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='PADME'), Node('Person', name='YODA'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='PADME'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='PADME'), Node('Droid', name='R2-D2'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='PADME'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='MACE WINDU'), Node('Person', name='PADME'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
# ...
#    APPEARS_IN(Node('Person', name='WALD'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'WALD'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='JABBA'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'JABBA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='RABE'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'RABE'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Droid', name='C-3PO'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='RIC OLIE'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'RIC OLIE'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='NUTE GUNRAY'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'NUTE GUNRAY'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='ANAKIN'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='TARPALS'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'TARPALS'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='OBI-WAN'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='GREEDO'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'GREEDO'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='GENERAL CEEL'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'GENERAL CEEL'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='PK-4'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'PK-4'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='TEY HOW'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'TEY HOW'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='KI-ADI-MUNDI'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'KI-ADI-MUNDI'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='JAR JAR'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'JAR JAR'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='BOSS NASS'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'BOSS NASS'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='CAPTAIN PANAKA'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'CAPTAIN PANAKA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='TC-14'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'TC-14'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='JIRA'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'JIRA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='KITSTER'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'KITSTER'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='EMPEROR'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='DOFINE'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'DOFINE'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='BAIL ORGANA'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'BAIL ORGANA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='MACE WINDU'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'MACE WINDU'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='BRAVO THREE'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'BRAVO THREE'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='VALORUM'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'VALORUM'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='FODE/BEED'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'FODE/BEED'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='SHMI'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'SHMI'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='SEBULBA'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'SEBULBA'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='PADME'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'PADME'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='QUI-GON'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'QUI-GON'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='DARTH MAUL'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'DARTH MAUL'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='WATTO'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'WATTO'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Person', name='SIO BIBBLE'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'SIO BIBBLE'},
#  {'n.name': 'YODA',
#   'r': [APPEARS_IN(Node('Person', name='YODA'), Node('Movie', name='Episode I: The Phantom Menace')),
#    APPEARS_IN(Node('Droid', name='R2-D2'), Node('Movie', name='Episode I: The Phantom Menace'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA'))],
#   'm.name': 'LUKE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Droid', name='R2-D2'))],
#   'm.name': 'R2-D2'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CHEWBACCA'), Node('Person', name='LUKE'))],
#   'm.name': 'CHEWBACCA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='JABBA'), Node('Person', name='LUKE'))],
#   'm.name': 'JABBA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='WEDGE'))],
#   'm.name': 'WEDGE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='LUKE'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='RED LEADER'))],
#   'm.name': 'RED LEADER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BIB FORTUNA'), Node('Person', name='LUKE'))],
#   'm.name': 'BIB FORTUNA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='RED TEN'))],
#   'm.name': 'RED TEN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BIGGS'), Node('Person', name='LUKE'))],
#   'm.name': 'BIGGS'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='LUKE'), Node('Movie', name='Episode IV: A New Hope'))],
#   'm.name': 'Episode IV: A New Hope'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='HAN'), Node('Person', name='LUKE'))],
#   'm.name': 'HAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CAMIE'), Node('Person', name='LUKE'))],
#   'm.name': 'CAMIE'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LEIA'), Node('Person', name='LUKE'))],
#   'm.name': 'LEIA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='BERU'), Node('Person', name='LUKE'))],
#   'm.name': 'BERU'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='DODONNA'), Node('Person', name='LUKE'))],
#   'm.name': 'DODONNA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='OWEN'))],
#   'm.name': 'OWEN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='REY'))],
#   'm.name': 'REY'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='LUKE'), Node('Movie', name='Episode VI: Return of the Jedi'))],
#   'm.name': 'Episode VI: Return of the Jedi'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='MON MOTHMA'))],
#   'm.name': 'MON MOTHMA'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='GOLD LEADER'), Node('Person', name='LUKE'))],
#   'm.name': 'GOLD LEADER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='LUKE'), Node('Movie', name='Episode VII: The Force Awakens'))],
#   'm.name': 'Episode VII: The Force Awakens'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='DARTH VADER'), Node('Person', name='LUKE'))],
#   'm.name': 'DARTH VADER'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='ZEV'))],
#   'm.name': 'ZEV'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='EMPEROR'), Node('Person', name='LUKE'))],
#   'm.name': 'EMPEROR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Droid', name='C-3PO'), Node('Person', name='LUKE'))],
#   'm.name': 'C-3PO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ADMIRAL ACKBAR'), Node('Person', name='LUKE'))],
#   'm.name': 'ADMIRAL ACKBAR'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='LUKE'), Node('Movie', name='Episode V: The Empire Strikes Back'))],
#   'm.name': 'Episode V: The Empire Strikes Back'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='DACK'), Node('Person', name='LUKE'))],
#   'm.name': 'DACK'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='LUKE'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='LANDO'), Node('Person', name='LUKE'))],
#   'm.name': 'LANDO'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='YODA'))],
#   'm.name': 'CLONE COMMANDER CODY'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='OBI-WAN'))],
#   'm.name': 'OBI-WAN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='ANAKIN'), Node('Person', name='CLONE COMMANDER CODY'))],
#   'm.name': 'ANAKIN'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='YODA')),
#    APPEARS_IN(Node('Person', name='CLONE COMMANDER CODY'), Node('Movie', name='Episode III: Revenge of the Sith'))],
#   'm.name': 'Episode III: Revenge of the Sith'},
#  {'n.name': 'YODA',
#   'r': [SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='YODA')),
#    SPEAKS_WITH(Node('Person', name='CLONE COMMANDER CODY'), Node('Person', name='MACE WINDU'))],
#   'm.name': 'MACE WINDU'}]
